# %%
dates = ['2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09', '2022-12-12', '2022-12-13', '2022-12-14']
finacial_data = [399.5899963378906, 393.8299865722656, 393.1600036621094, 396.239990234375, 393.2799987792969, 398.95001220703125, 401.9700012207031, 399.3999938964844]

sentscores = [0.05894886363636364, 0.053541550474065815, 0.06270411495754409, 0.07077326343381389, 0.05615696887686062, 0.06750741839762611, 0.05512744516893894, 0.06666666666666667]

#this is with one batch of 13,069 articles, 30k attempts. Sampled from most recent.

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(len(finacial_data))
plt.plot(x, finacial_data)
plt.xlabel('dates')
plt.ylabel('stock price')
plt.show()
plt.plot(x, sentscores)
plt.xlabel('dates')
plt.ylabel('sentiment score')
plt.show()
#normalize data 
finacial_data_plt = (finacial_data - np.mean(finacial_data))/np.std(finacial_data)
sentscores_plt = (sentscores - np.mean(sentscores))/np.std(sentscores)
plt.plot(x, finacial_data_plt)
plt.plot(x, sentscores_plt)
plt.xlabel('dates')
plt.ylabel('normalized stock price and sentiment score')
plt.show()

print(sentscores)
print(finacial_data)
print(dates)

#this is the ratio of positive to total articles for the day, rather than negatives
# Out:
# [0.05894886363636364, 0.053541550474065815, 0.06270411495754409, 0.07077326343381389, 0.05615696887686062, 0.06750741839762611, 0.05512744516893894, 0.06666666666666667]
# [399.5899963378906, 393.8299865722656, 393.1600036621094, 396.239990234375, 393.2799987792969, 398.95001220703125, 401.9700012207031, 399.3999938964844]
# ['2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08', '2022-12-09', '2022-12-12', '2022-12-13', '2022-12-14']

# %%
#our next run is with 400 articles, 45 crawls, sampled from most recent.  18k articles total.
# positives 331
# negatives 25
# [13.24]
# [399.3999938964844]
# ['2022-12-14']

#our next run is with 200 articles, 150 crawls, sampled from most recent.  30k articles total.
#10k viable articles, with 159 on the 9th, 169 on the 12th, 170 on the 13th and 183 on the 14th


sentscores = [12.25, 14.363636363636363, 11.142857142857142, 13.076923076923077]
finacial_data = [393.2799987792969, 398.95001220703125, 401.9700012207031, 399.3999938964844]
dates = ['2022-12-09', '2022-12-12', '2022-12-13', '2022-12-14']


import matplotlib.pyplot as plt
import numpy as np
x = np.arange(len(finacial_data))
plt.plot(x, finacial_data)
plt.xlabel('dates')
plt.ylabel('stock price')
plt.show()
plt.plot(x, sentscores)
plt.xlabel('dates')
plt.ylabel('sentiment score')
plt.show()
#normalize data 
finacial_data_plt = (finacial_data - np.mean(finacial_data))/np.std(finacial_data)
sentscores_plt = (sentscores - np.mean(sentscores))/np.std(sentscores)
plt.plot(x, finacial_data_plt)
plt.plot(x, sentscores_plt)
plt.xlabel('dates from 12/9 to 12/14, excluding the weekend')
plt.ylabel('normalized stock price and sentiment score')
plt.show()

print(sentscores)
print(finacial_data)
print(dates)
# Out:
# [12.25, 14.363636363636363, 11.142857142857142, 13.076923076923077]
# [393.2799987792969, 398.95001220703125, 401.9700012207031, 399.3999938964844]
# ['2022-12-09', '2022-12-12', '2022-12-13', '2022-12-14']

# %%
#randomly sampled 70 warcs, with 350 articles each:
sentscores = [2.5, 10.0, 7.0, 4.0, 2.0, 4, 2.4545454545454546, 16.0, 14.0, 1.4285714285714286, 22, 6.333333333333333, 25.0, 1.0, 6.0, 13.0, 31, 18.0, 10, 11.0]
finacial_data = [224.11793518066406, 233.6909637451172, 241.56446838378906, 252.62460327148438, 274.0174560546875, 270.468017578125, 271.544189453125, 282.5121765136719, 307.15228271484375, 317.6770935058594, 361.5975341796875, 377.0892639160156, 416.221435546875, 433.05853271484375, 439.8830871582031, 462.72802734375, 447.7657165527344, 412.2271728515625, 372.8583679199219, 382.0]
dates= ['2017-08-22', '2017-10-05', '2017-12-06', '2018-05-24', '2019-04-22', '2019-05-21', '2019-06-07', '2019-09-05', '2019-12-20', '2020-01-23', '2020-12-17', '2021-03-02', '2021-06-14', '2021-07-26', '2021-08-24', '2021-11-18', '2022-02-01', '2022-03-14', '2022-06-22', '2022-11-08']

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(len(finacial_data))
plt.plot(x, finacial_data)
plt.xlabel('dates')
plt.ylabel('stock price')
plt.show()
plt.plot(x, sentscores)
plt.xlabel('dates')
plt.ylabel('sentiment score')
plt.show()
#normalize data 
finacial_data_plt = (finacial_data - np.mean(finacial_data))/np.std(finacial_data)
sentscores_plt = (sentscores - np.mean(sentscores))/np.std(sentscores)
plt.plot(x, finacial_data_plt)
plt.plot(x, sentscores_plt)
plt.xlabel('dates from 2017-08-22 to 2022-11-08, randomly sampled 70 points')
plt.ylabel('normalized stock price and sentiment score')
plt.show()
